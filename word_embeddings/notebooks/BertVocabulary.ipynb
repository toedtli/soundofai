# %%
# !pip install transformers
# !pip install sentence_transformers
# Out:
# ...
#      |████████████████████████████████| 1.8MB 8.7MB/s
# ...
#      |████████████████████████████████| 3.2MB 30.8MB/s
# ...
#      |████████████████████████████████| 890kB 54.9MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=8c676337aad1bb007044776f945f335b6410fb3e01df078fcb720e8f3e7a84b4
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#      |████████████████████████████████| 71kB 4.2MB/s
# ...
#      |████████████████████████████████| 1.2MB 10.6MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-0.4.1.2-cp36-none-any.whl size=103068 sha256=fa939dc0c80adb2d1325718963512889188315f7214782775517c2dea4640bbe
#   Stored in directory: /root/.cache/pip/wheels/3d/33/d1/5703dd56199c09d4a1b41e0c07fb4e7765a84d787cbdc48ac3
# Successfully built sentence-transformers
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cef087773792> in <module>()
# ----> 1 tokenizer.vocab.keys()
#
# NameError: name 'tokenizer' is not defined

# %%
from transformers import AutoTokenizer
from sentence_transformers import SentenceTransformer

# %%
#SentenceTransformer('sentence-transformers/bert-base-nli-mean-tokens')

# %%
HuggingFaceURL = 'sentence-transformers/bert-base-nli-mean-tokens'
preprocessor = AutoTokenizer.from_pretrained(HuggingFaceURL)

# %%
preprocessor.vocab.keys()
# Out:
# dict_keys(['same', 'gross', 'count', '[unused819]', '##cona', 'pulses', 'past', 'jerusalem', '##ই', 'bind', 'gujarat', 'ankles', 'possibilities', '1865', 'weiss', 'shirts', 'authorized', '##39', 'knowing', 'glossy', 'aragon', 'scarlett', '##ran', 'cameron', 'boring', 'hospice', 'rosenberg', 'nasa', '[unused609]', 'smiling', 'looked', 'warped', 'hollis', '##sell', '##aer', 'remarried', '##lini', 'marriott', '福', 'dripping', 'tamil', 'rare', '##yang', 'wryly', 'gill', 'sparked', 'stephen', 'bushes', 'nearing', 'suffix', 'emma', 'covered', 'armour', 'emeritus', '・', '##unda', '##iring', 'battery', 'rained', 'using', 'founded', 'combo', 'senators', 'examinations', 'bae', 'via', '##vier', 'licensing', 'espionage', 'projective', '##jah', 'width', 'samples', '##2', '##ech', 'broadband', 'earthly', 'emphasize', 'batman', 'bonn', 'clarence', 'julia', 'cordoba', 'spinal', '##romatic', '1962', 'magnolia', 'ridges', '⁰', 'namely', 'citizens', 'trait', 'barbarian', '1757', 'dad', 'dame', 'dripped
# ...

# %%
instrumentlist = list(set("accordina accordion algozey alphorn treble alto tenor alto alto arghul bellow bandoneón bansuri baritone baritone sackbut baroque bass basset basset bass bass bass bass bass bass bass bawu bayan bellowed birbyne brass recorder boatswain bronze Cembalet chalumeau chirimía chromatic chromatic cimbasso cornamuse daegeum calliope Anglo German diatonic didgeridoo ding ding dizi double barrel bagpipe duduk dulzaina free single English English cor duck E euphonium fipple flabiol flageolet flûte flute flugelhorn fourth fujara footbass garklein gemshorn gralla great guan härjedalspipa harmonium heckelphone hichiriki hmông woodwind bugle hue hulusi Irish jug k kagurabue kaval kèn khene kèn khèn khlui ki theatre keyed clarinet button accordion koauau koauau slide cont
# %%
not_found_instruments = [instrument for instrument in instrumentlist if instrument not in found_instruments]

# %%
n = len(found_instruments)+len(not_found_instruments)
ratio = len(found_instruments)/n*100
print(f'Found {len(found_instruments)} ({ratio:2.0f}%) of {n} instruments in {HuggingFaceURL}')
# Out:
# Found 165 (21%) of 774 instruments in sentence-transformers/bert-base-nli-mean-tokens

# %%
','.join(not_found_instruments)
# Out:
# 'chanzy,alfaia,boobam,archtop,ajaeng,kantele,alphorn,nyatiti,goblet,kotsuzumi,š,kös,timpani,pakuru,steelpan,craviola,nohkan,snare,E,poi,kecer,violone,caxixi,mandola,uilleann,quadruple,marímbula,balalaika,Swedish,bawu,pemade,chime,huqin,tamborim,agogô,gendèr,shudraga,morsing,kinnor,chitra,Most,Schwyzerörgeli,dobro,pí,suikinkutsu,vocoder,taiko,kempli,kantilan,kendhang,ghatam,thavil,claves,dunun,slentho,gehu,dutar,krar,Pianet,There,pkhachich,jantar,lira,quinto,keytar,Baltic,cajón,bangu,jublag,crumhorn,atabaque,diatonic,sabar,setar,tràm,djoza,chacha,talharpa,castanets,paiban,limbe,zabumba,charango,fipple,Unclassified,elektronium,kudüm,zhuihu,gambang,tabla,For,reeds,Spanish,klong,saron,gadulka,kortholt,ghaychak,farfisa,It,sursingar,theorbo,congas,Electronic,vibrandoneon,ratchet,zaqq,ektara,Mexican,chande,hichiriki,akkordolia,oud,dulce,naobo,tokere,Cretan,valiha,duxianqin,laúd,kazoo,lyre,pahu,taonga,cornamuse,güiro,Often,Tibetan,tromba,mandocello,kkwaenggwari,zurna,gamelan,Hammond,chitarra
# ...

# %%
','.join(found_instruments)
# Out:
# 'rhythm,great,duck,barrel,brass,tape,effects,bell,shaken,finger,ankle,gut,jug,harp,free,musical,t,whistle,lap,wooden,brushes,tenor,fourth,bones,tom,baritone,valve,17,ching,five,other,serpent,nose,tr,hard,oboe,stick,trumpet,12,tangent,concert,upright,practice,triangle,button,toy,cello,concussion,folk,saxophone,jing,song,bellowed,flute,talking,banjo,hue,ti,body,viola,electronic,tin,samba,fiddle,end,cylindrical,traditional,scraped,ding,pocket,wire,pan,spike,reed,struck,willow,harpsichord,pang,pi,clarinet,continuum,tap,strings,bowed,wood,grand,tres,prepared,string,recorder,tuba,xiao,tubular,pipe,slide,foot,game,wind,drum,bass,accordion,keyboard,hammered,single,soprano,mouth,double,electric,unspecified,birch,regal,bicycle,mendoza,theatre,yu,pedal,hi,steel,natural,fife,mandolin,whip,analog,bin,three,gong,guitar,ng,vessel,sho,tack,alto,friction,laser,k,piano,tar,classical,ki,sheng,vacuum,bronze,table,low,nylon,harmonica,four,kettle,slit,acoustic,saw,baroque,transverse,te,glass,trombone,rena
# ...
